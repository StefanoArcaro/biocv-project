# %% [markdown]
# ## Imports and settings

# %%
# Fix randomness and hide warnings
seed = 1234

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras
from keras import backend
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.15.0

# %%
# Check if tensorflow is using GPU
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import utils
import albumentations as A

# %% [markdown]
# ## Load the data

# %%
T1_samples_loaded, T2_samples_loaded, T1_labels_loaded, T2_labels_loaded = utils.load_preprocessed_data_train()

# %% [markdown]
# ## Prepare the data for the network

# %%
T1_data_samples, T2_data_samples, T1_data_labels, T2_data_labels = utils.prepare_data_for_training(T1_samples_loaded, T2_samples_loaded, T1_labels_loaded, T2_labels_loaded)
# Out:
# Preparing T1 samples for training...
# - Vertically stacking the samples from all patients...
# - Adding a channel dimension to the samples...
# - Normalizing the samples with min-max scaling...
# Samples shape: (640, 272, 272, 1)
#
# Preparing T2 samples for training...
# - Vertically stacking the samples from all patients...
# - Adding a channel dimension to the samples...
# - Normalizing the samples with min-max scaling...
# Samples shape: (640, 272, 272, 1)
#
# Preparing T1 labels for training...
# - Vertically stacking the labels from all patients...
# - Creating masks for the different categories...
# Labels shape: (640, 272, 272, 1)
#
# Preparing T2 labels for training...
# - Vertically stacking the labels from all patients...
# - Creating masks for the different categories...
# Labels shape: (640, 272, 272, 1)

# %%
# Vertically stack the T1 and T2 data (samples and labels)
data_samples = np.vstack((T1_data_samples, T2_data_samples))
data_labels = np.vstack((T1_data_labels, T2_data_labels))

# Print the shape of the data
print(data_samples.shape)
print(data_labels.shape)
# Out:
# (1280, 272, 272, 1)
# (1280, 272, 272, 1)

# %%
# Split the data into training, validation and test sets
X_train, X_val, X_test, y_train, y_val, y_test = utils.split_data_for_training(data_samples, data_labels)
# Out:
# Splitting the data into training, validation and test sets...
#     Train samples shape: (880, 272, 272, 1)
#     Train labels shape: (880, 272, 272, 1)
#     Validation samples shape: (200, 272, 272, 1)
#     Validation labels shape: (200, 272, 272, 1)
#     Test samples shape: (200, 272, 272, 1)
#     Test labels shape: (200, 272, 272, 1)

# %%
input_shape = X_train[0].shape
num_classes = len(np.unique(y_train))
print(f"Input shape: {input_shape}")
print(f"Number of classes: {num_classes}")
# Out:
# Input shape: (272, 272, 1)
# Number of classes: 5

# %% [markdown]
# ## Create the model and a custom IOU metric

# %%
# Create the UNet model
model = utils.get_unet_model(input_shape=T1_data_samples[0].shape, num_classes=len(np.unique(T1_data_labels)))
model.summary()
# Out:
# Model: "unet_model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 272, 272, 1)]        0         []
#
#  down_block1_conv1 (Conv2D)  (None, 272, 272, 64)         640       ['input_layer[0][0]']
#
#  down_block1_bn1 (BatchNorm  (None, 272, 272, 64)         256       ['down_block1_conv1[0][0]']
#  alization)
#
#  down_block1_act1 (Activati  (None, 272, 272, 64)         0         ['down_block1_bn1[0][0]']
#  on)
#
#  down_block1_conv2 (Conv2D)  (None, 272, 272, 64)         36928     ['down_block1_act1[0][0]']
#
#  down_block1_bn2 (BatchNorm  (None, 272, 272, 64)         256       ['down_block1_conv2[0][0]']
#  alization)
#
#  down_block1_act2 (Activati  (None, 272, 272, 64)         0         ['down_block1_bn2[0][0]']
#  on)
#
#  max_pooling2d (MaxPooling2  (None, 136, 136, 64)         0         ['down_block1_act2[0][0]']
#  D)
#
#  down_block2_conv1 (Conv2D)  (None, 136, 136, 128)        73856     ['max_pooling2d[0][0]']
#
#  down_block2_bn1 (BatchNorm  (None, 136, 136, 128)        512       ['down_block2_conv1[0][0]']
#  alization)
#
#  down_block2_act1 (Activati  (None, 136, 136, 128)        0         ['down_block2_bn1[0][0]']
#  on)
#
#  down_block2_conv2 (Conv2D)  (None, 136, 136, 128)        147584    ['down_block2_act1[0][0]']
#
#  down_block2_bn2 (BatchNorm  (None, 136, 136, 128)        512       ['down_block2_conv2[0][0]']
#  alization)
#
#  down_block2_act2 (Activati  (None, 136, 136, 128)        0         ['down_block2_bn2[0][0]']
#  on)
#
#  max_pooling2d_1 (MaxPoolin  (None, 68, 68, 128)          0         ['down_block2_act2[0][0]']
#  g2D)
#
#  down_block3_conv1 (Conv2D)  (None, 68, 68, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  down_block3_bn1 (BatchNorm  (None, 68, 68, 256)          1024      ['down_block3_conv1[0][0]']
#  alization)
#
#  down_block3_act1 (Activati  (None, 68, 68, 256)          0         ['down_block3_bn1[0][0]']
#  on)
#
#  down_block3_conv2 (Conv2D)  (None, 68, 68, 256)          590080    ['down_block3_act1[0][0]']
#
#  down_block3_bn2 (BatchNorm  (None, 68, 68, 256)          1024      ['down_block3_conv2[0][0]']
#  alization)
#
#  down_block3_act2 (Activati  (None, 68, 68, 256)          0         ['down_block3_bn2[0][0]']
#  on)
#
#  max_pooling2d_2 (MaxPoolin  (None, 34, 34, 256)          0         ['down_block3_act2[0][0]']
#  g2D)
#
#  down_block4_conv1 (Conv2D)  (None, 34, 34, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  down_block4_bn1 (BatchNorm  (None, 34, 34, 512)          2048      ['down_block4_conv1[0][0]']
#  alization)
#
#  down_block4_act1 (Activati  (None, 34, 34, 512)          0         ['down_block4_bn1[0][0]']
#  on)
#
#  down_block4_conv2 (Conv2D)  (None, 34, 34, 512)          2359808   ['down_block4_act1[0][0]']
#
#  down_block4_bn2 (BatchNorm  (None, 34, 34, 512)          2048      ['down_block4_conv2[0][0]']
#  alization)
#
#  down_block4_act2 (Activati  (None, 34, 34, 512)          0         ['down_block4_bn2[0][0]']
#  on)
#
#  max_pooling2d_3 (MaxPoolin  (None, 17, 17, 512)          0         ['down_block4_act2[0][0]']
#  g2D)
#
#  bottleneckconv1 (Conv2D)    (None, 17, 17, 512)          2359808   ['max_pooling2d_3[0][0]']
#
#  bottleneckbn1 (BatchNormal  (None, 17, 17, 512)          2048      ['bottleneckconv1[0][0]']
#  ization)
#
#  bottleneckact1 (Activation  (None, 17, 17, 512)          0         ['bottleneckbn1[0][0]']
#  )
#
#  bottleneckconv2 (Conv2D)    (None, 17, 17, 512)          2359808   ['bottleneckact1[0][0]']
#
#  bottleneckbn2 (BatchNormal  (None, 17, 17, 512)          2048      ['bottleneckconv2[0][0]']
#  ization)
#
#  bottleneckact2 (Activation  (None, 17, 17, 512)          0         ['bottleneckbn2[0][0]']
#  )
#
#  up_sampling2d (UpSampling2  (None, 34, 34, 512)          0         ['bottleneckact2[0][0]']
#  D)
#
#  concatenate1 (Concatenate)  (None, 34, 34, 1024)         0         ['up_sampling2d[0][0]',
#                                                                      'down_block4_act2[0][0]']
#
#  up_block1_conv1 (Conv2D)    (None, 34, 34, 256)          2359552   ['concatenate1[0][0]']
#
#  up_block1_bn1 (BatchNormal  (None, 34, 34, 256)          1024      ['up_block1_conv1[0][0]']
#  ization)
#
#  up_block1_act1 (Activation  (None, 34, 34, 256)          0         ['up_block1_bn1[0][0]']
#  )
#
#  up_block1_conv2 (Conv2D)    (None, 34, 34, 256)          590080    ['up_block1_act1[0][0]']
#
#  up_block1_bn2 (BatchNormal  (None, 34, 34, 256)          1024      ['up_block1_conv2[0][0]']
#  ization)
#
#  up_block1_act2 (Activation  (None, 34, 34, 256)          0         ['up_block1_bn2[0][0]']
#  )
#
#  up_sampling2d_1 (UpSamplin  (None, 68, 68, 256)          0         ['up_block1_act2[0][0]']
#  g2D)
#
#  concatenate2 (Concatenate)  (None, 68, 68, 512)          0         ['up_sampling2d_1[0][0]',
#                                                                      'down_block3_act2[0][0]']
#
#  up_block2_conv1 (Conv2D)    (None, 68, 68, 128)          589952    ['concatenate2[0][0]']
#
#  up_block2_bn1 (BatchNormal  (None, 68, 68, 128)          512       ['up_block2_conv1[0][0]']
#  ization)
#
#  up_block2_act1 (Activation  (None, 68, 68, 128)          0         ['up_block2_bn1[0][0]']
#  )
#
#  up_block2_conv2 (Conv2D)    (None, 68, 68, 128)          147584    ['up_block2_act1[0][0]']
#
#  up_block2_bn2 (BatchNormal  (None, 68, 68, 128)          512       ['up_block2_conv2[0][0]']
#  ization)
#
#  up_block2_act2 (Activation  (None, 68, 68, 128)          0         ['up_block2_bn2[0][0]']
#  )
#
#  up_sampling2d_2 (UpSamplin  (None, 136, 136, 128)        0         ['up_block2_act2[0][0]']
#  g2D)
#
#  concatenate3 (Concatenate)  (None, 136, 136, 256)        0         ['up_sampling2d_2[0][0]',
#                                                                      'down_block2_act2[0][0]']
#
#  up_block3_conv1 (Conv2D)    (None, 136, 136, 64)         147520    ['concatenate3[0][0]']
#
#  up_block3_bn1 (BatchNormal  (None, 136, 136, 64)         256       ['up_block3_conv1[0][0]']
#  ization)
#
#  up_block3_act1 (Activation  (None, 136, 136, 64)         0         ['up_block3_bn1[0][0]']
#  )
#
#  up_block3_conv2 (Conv2D)    (None, 136, 136, 64)         36928     ['up_block3_act1[0][0]']
#
#  up_block3_bn2 (BatchNormal  (None, 136, 136, 64)         256       ['up_block3_conv2[0][0]']
#  ization)
#
#  up_block3_act2 (Activation  (None, 136, 136, 64)         0         ['up_block3_bn2[0][0]']
#  )
#
#  up_sampling2d_3 (UpSamplin  (None, 272, 272, 64)         0         ['up_block3_act2[0][0]']
#  g2D)
#
#  concatenate4 (Concatenate)  (None, 272, 272, 128)        0         ['up_sampling2d_3[0][0]',
#                                                                      'down_block1_act2[0][0]']
#
#  up_block4_conv1 (Conv2D)    (None, 272, 272, 64)         73792     ['concatenate4[0][0]']
#
#  up_block4_bn1 (BatchNormal  (None, 272, 272, 64)         256       ['up_block4_conv1[0][0]']
#  ization)
#
#  up_block4_act1 (Activation  (None, 272, 272, 64)         0         ['up_block4_bn1[0][0]']
#  )
#
#  up_block4_conv2 (Conv2D)    (None, 272, 272, 64)         36928     ['up_block4_act1[0][0]']
#
#  up_block4_bn2 (BatchNormal  (None, 272, 272, 64)         256       ['up_block4_conv2[0][0]']
#  ization)
#
#  up_block4_act2 (Activation  (None, 272, 272, 64)         0         ['up_block4_bn2[0][0]']
#  )
#
#  output_layer (Conv2D)       (None, 272, 272, 5)          2885      ['up_block4_act2[0][0]']
#
# ==================================================================================================
# Total params: 13404933 (51.14 MB)
# Trainable params: 13396997 (51.11 MB)
# Non-trainable params: 7936 (31.00 KB)
# __________________________________________________________________________________________________

# %%
# Define a custom metric class for mean intersection over union (IoU)
@keras.utils.register_keras_serializable()
class UpdatedMeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes=None, name="mean_iou", dtype=None):
        super(UpdatedMeanIoU, self).__init__(num_classes=num_classes, name=name, dtype=dtype)

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.math.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# %% [markdown]
# ## Create a data augmentation pipeline

# %%
class CustomDataGenerator(keras.utils.Sequence):
    def __init__(self, data, labels, batch_size, augmentations=None):
        self.data = data
        self.labels = labels
        self.batch_size = batch_size
        self.augmentations = augmentations
        self.indexes = np.arange(len(self.data))

    def __len__(self):
        return int(np.ceil(len(self.data) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size

        # Handle the last batch if it doesn't evenly divide the dataset length
        if end > len(self.data):
            end = len(self.data)

        batch_data = self.data[start:end]
        batch_labels = self.labels[start:end]

        augmented_data = []
        augmented_labels = []

        for data_item, label_item in zip(batch_data, batch_labels):
            if self.augmentations:

                # Convert data to float32 and labels to int32 for best performance
                data_item = data_item.astype(np.float32)
                label_item = label_item.astype(np.int32)
                
                # Apply augmentations to the image and mask
                augmented = self.augmentations(image=data_item, mask=label_item)
                data_item = augmented['image']
                label_item = augmented['mask']

            augmented_data.append(data_item)
            augmented_labels.append(label_item)

        # Convert the list of augmented images and labels to a numpy array
        augmented_data = np.array(augmented_data)
        augmented_labels = np.array(augmented_labels)

        return augmented_data, augmented_labels

# %%
# Define a function to convert images to uint8 and back to float32
def to_uint8(image, **kwargs):
    return (image * 255).astype('uint8')

def to_float32(image, **kwargs):
    return image.astype('float32') / 255.0

# Create the data augmentation pipeline
augmentation_pipeline = A.Compose([
    A.Rotate(limit=15, p=0.5),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.Lambda(image=to_uint8),
    A.Equalize(p=0.5),
    A.Lambda(image=to_float32)
])

# %% [markdown]
# ## Train the model

# %%
# Free up RAM
del T1_samples_loaded, T2_samples_loaded, T1_labels_loaded, T2_labels_loaded, T1_data_samples, T2_data_samples, T1_data_labels, T2_data_labels, data_samples, data_labels

# %%
# Define input parameters
input_shape = X_train[0].shape
num_classes = len(np.unique(y_train))

# Define hyperparameters
learning_rate = 1e-3
batch_size = 8
epochs = 1000

# Define compile parameters
loss = keras.losses.SparseCategoricalCrossentropy()
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
metrics = ['accuracy', UpdatedMeanIoU(num_classes=num_classes)]

# Define callbacks
patience = 30
early_stopping = keras.callbacks.EarlyStopping(monitor='val_mean_iou', mode='max', patience=patience, restore_best_weights=True)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_mean_iou', mode='max', factor=0.1, patience=patience-10, min_lr=1e-6)

# %%
# Instantiate the data generator
data_generator = CustomDataGenerator(X_train, y_train, batch_size=batch_size, augmentations=augmentation_pipeline)

# %%
# Compile the model
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Train the model
history = model.fit(
    data_generator,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1702858583.387369  498168 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 110/110 [==============================] - 58s 289ms/step - loss: 0.2622 - accuracy: 0.9790 - mean_iou: 0.1919 - val_loss: 0.5524 - val_accuracy: 1.0000 - val_mean_iou: 0.1923 - lr: 0.0010
# Epoch 2/1000
# 110/110 [==============================] - 26s 235ms/step - loss: 0.1824 - accuracy: 0.9999 - mean_iou: 0.1921 - val_loss: 0.3813 - val_accuracy: 1.0000 - val_mean_iou: 0.1923 - lr: 0.0010
# Epoch 3/1000
# 110/110 [==============================] - 26s 236ms/step - loss: 0.1666 - accuracy: 0.9986 - mean_iou: 0.1958 - val_loss: 0.5365 - val_accuracy: 0.5382 - val_mean_iou: 0.1241 - lr: 0.0010
# Epoch 4/1000
# 110/110 [==============================] - 26s 236ms/step - loss: 0.1458 - accuracy: 0.9956 - mean_iou: 0.2058 - val_loss: 0.2431 - val_accuracy: 1.0000 - val_mean_iou: 0.1923 - lr: 0.0010
# Epoch 5/1000
# 110/110 [==============================] - 26s 237ms/step - loss: 0.1399 - accuracy: 0.9940 - mean_iou: 0.2087 - val_loss: 0.1674 - val_accuracy: 0.9986 - val_mean_iou: 0.1981 - lr: 0.0010
# Epoch 6/1000
# 110/110 [==============================] - 26s 236ms/step - loss: 0.1369 - accuracy: 0.9933 - mean_iou: 0.2123 - val_loss: 0.1135 - val_accuracy: 0.9921 - val_mean_iou: 0.2218 - lr: 0.0010
# Epoch 7/1000
# 110/110 [==============================] - 26s 236ms/step - loss: 0.1265 - accuracy: 0.9918 - mean_iou: 0.2176 - val_loss: 0.1383 - val_accuracy: 1.0000 - val_mean_iou: 0.1923 - lr: 0.0010
# Epoch 8/1000
# 110/110 [==============================] - 26s 237ms/step - loss: 0.1254 - accuracy: 0.9880 - mean_iou: 0.2285 - val_loss: 0.1750 - val_accuracy: 1.0000 - val_mean_iou: 0.1923 - lr: 0.0010
# Epoch 9/1000
# 110/110 [==============================] - 26s 239ms/step - loss: 0.1209 - accuracy: 0.9869 - mean_iou: 0.2361 - val_loss: 0.1218 - val_accuracy: 0.9746 - val_mean_iou: 0.2492 - lr: 0.0010
# Epoch 10/1000
# 110/110 [==============================] - 26s 237ms/step - loss: 0.1096 - accuracy: 0.9821 - mean_iou: 0.2527 - val_loss: 0.1207 - val_accuracy: 0.9919 - val_mean_iou: 0.2272 - lr: 0.0010
# Epoch 11/1000
# 110/110 [==============================] - 26s 238ms/step - loss: 0
1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0152 - accuracy: 0.9618 - mean_iou: 0.8359 - val_loss: 0.0211 - val_accuracy: 0.9625 - val_mean_iou: 0.8056 - lr: 1.0000e-04
# Epoch 96/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0164 - accuracy: 0.9620 - mean_iou: 0.8271 - val_loss: 0.0209 - val_accuracy: 0.9633 - val_mean_iou: 0.8045 - lr: 1.0000e-04
# Epoch 97/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0158 - accuracy: 0.9619 - mean_iou: 0.8344 - val_loss: 0.0209 - val_accuracy: 0.9634 - val_mean_iou: 0.8040 - lr: 1.0000e-04
# Epoch 98/1000
# 110/110 [==============================] - 25s 232ms/step - loss: 0.0158 - accuracy: 0.9619 - mean_iou: 0.8352 - val_loss: 0.0205 - val_accuracy: 0.9633 - val_mean_iou: 0.8046 - lr: 1.0000e-04
# Epoch 99/1000
# 110/110 [==============================] - 26s 232ms/step - loss: 0.0162 - accuracy: 0.9623 - mean_iou: 0.8317 - val_loss: 0.0207 - val_accuracy: 0.9632 - val_mean_iou: 0.8065 - lr: 1.0000e-04
# Epoch 100/1000
# 110/110 [==============================] - 25s 232ms/step - loss: 0.0157 - accuracy: 0.9621 - mean_iou: 0.8343 - val_loss: 0.0208 - val_accuracy: 0.9627 - val_mean_iou: 0.8071 - lr: 1.0000e-04
# Epoch 101/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0151 - accuracy: 0.9619 - mean_iou: 0.8376 - val_loss: 0.0214 - val_accuracy: 0.9635 - val_mean_iou: 0.8054 - lr: 1.0000e-04
# Epoch 102/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0155 - accuracy: 0.9622 - mean_iou: 0.8375 - val_loss: 0.0207 - val_accuracy: 0.9628 - val_mean_iou: 0.8095 - lr: 1.0000e-04
# Epoch 103/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0153 - accuracy: 0.9619 - mean_iou: 0.8367 - val_loss: 0.0207 - val_accuracy: 0.9629 - val_mean_iou: 0.8078 - lr: 1.0000e-04
# Epoch 104/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0160 - accuracy: 0.9621 - mean_iou: 0.8346 - val_loss: 0.0208 - val_accuracy: 0.9635 - val_mean_iou: 0.8056 - lr: 1.0000e-04
# Epoch 105/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0154 - accuracy: 0.9621 - mean_iou: 0.8363 - val_loss: 0.0207 - val_accuracy: 0.9633 - val_mean_iou: 0.8081 - lr: 1.0000e-04
# Epoch 106/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0153 - accuracy: 0.9621 - mean_iou: 0.8375 - val_loss: 0.0207 - val_accuracy: 0.9632 - val_mean_iou: 0.8076 - lr: 1.0000e-04
# Epoch 107/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0166 - accuracy: 0.9623 - mean_iou: 0.8316 - val_loss: 0.0209 - val_accuracy: 0.9639 - val_mean_iou: 0.8052 - lr: 1.0000e-04
# Epoch 108/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0150 - accuracy: 0.9620 - mean_iou: 0.8374 - val_loss: 0.0210 - val_accuracy: 0.9626 - val_mean_iou: 0.8089 - lr: 1.0000e-04
# Epoch 109/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0146 - accuracy: 0.9619 - mean_iou: 0.8399 - val_loss: 0.0208 - val_accuracy: 0.9630 - val_mean_iou: 0.8091 - lr: 1.0000e-04
# Epoch 110/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0152 - accuracy: 0.9621 - mean_iou: 0.8386 - val_loss: 0.0210 - val_accuracy: 0.9637 - val_mean_iou: 0.8074 - lr: 1.0000e-04
# Epoch 111/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0149 - accuracy: 0.9618 - mean_iou: 0.8413 - val_loss: 0.0211 - val_accuracy: 0.9634 - val_mean_iou: 0.8085 - lr: 1.0000e-04
# Epoch 112/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0148 - accuracy: 0.9619 - mean_iou: 0.8387 - val_loss: 0.0212 - val_accuracy: 0.9630 - val_mean_iou: 0.8087 - lr: 1.0000e-04
# Epoch 113/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0145 - accuracy: 0.9618 - mean_iou: 0.8434 - val_loss: 0.0212 - val_accuracy: 0.9639 - val_mean_iou: 0.8052 - lr: 1.0000e-04
# Epoch 114/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0151 - accuracy: 0.9622 - mean_iou: 0.8420 - val_loss: 0.0209 - val_accuracy: 0.9633 - val_mean_iou: 0.8076 - lr: 1.0000e-04
# Epoch 115/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0155 - accuracy: 0.9621 - mean_iou: 0.8365 - val_loss: 0.0215 - val_accuracy: 0.9631 - val_mean_iou: 0.8067 - lr: 1.0000e-04
# Epoch 116/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0148 - accuracy: 0.9620 - mean_iou: 0.8391 - val_loss: 0.0212 - val_accuracy: 0.9628 - val_mean_iou: 0.8089 - lr: 1.0000e-04
# Epoch 117/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0154 - accuracy: 0.9622 - mean_iou: 0.8379 - val_loss: 0.0214 - val_accuracy: 0.9633 - val_mean_iou: 0.8078 - lr: 1.0000e-04
# Epoch 118/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0149 - accuracy: 0.9620 - mean_iou: 0.8393 - val_loss: 0.0216 - val_accuracy: 0.9626 - val_mean_iou: 0.8090 - lr: 1.0000e-04
# Epoch 119/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0151 - accuracy: 0.9621 - mean_iou: 0.8430 - val_loss: 0.0217 - val_accuracy: 0.9632 - val_mean_iou: 0.8089 - lr: 1.0000e-04
# Epoch 120/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0144 - accuracy: 0.9620 - mean_iou: 0.8435 - val_loss: 0.0215 - val_accuracy: 0.9633 - val_mean_iou: 0.8083 - lr: 1.0000e-04
# Epoch 121/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0144 - accuracy: 0.9620 - mean_iou: 0.8433 - val_loss: 0.0215 - val_accuracy: 0.9630 - val_mean_iou: 0.8060 - lr: 1.0000e-04
# Epoch 122/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0148 - accuracy: 0.9620 - mean_iou: 0.8425 - val_loss: 0.0213 - val_accuracy: 0.9629 - val_mean_iou: 0.8083 - lr: 1.0000e-04
# Epoch 123/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0156 - accuracy: 0.9625 - mean_iou: 0.8362 - val_loss: 0.0212 - val_accuracy: 0.9631 - val_mean_iou: 0.8083 - lr: 1.0000e-05
# Epoch 124/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0148 - accuracy: 0.9621 - mean_iou: 0.8420 - val_loss: 0.0212 - val_accuracy: 0.9631 - val_mean_iou: 0.8088 - lr: 1.0000e-05
# Epoch 125/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0143 - accuracy: 0.9620 - mean_iou: 0.8450 - val_loss: 0.0213 - val_accuracy: 0.9632 - val_mean_iou: 0.8086 - lr: 1.0000e-05
# Epoch 126/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0147 - accuracy: 0.9620 - mean_iou: 0.8417 - val_loss: 0.0214 - val_accuracy: 0.9633 - val_mean_iou: 0.8081 - lr: 1.0000e-05
# Epoch 127/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0144 - accuracy: 0.9621 - mean_iou: 0.8446 - val_loss: 0.0214 - val_accuracy: 0.9633 - val_mean_iou: 0.8087 - lr: 1.0000e-05
# Epoch 128/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0145 - accuracy: 0.9620 - mean_iou: 0.8449 - val_loss: 0.0214 - val_accuracy: 0.9632 - val_mean_iou: 0.8087 - lr: 1.0000e-05
# Epoch 129/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0148 - accuracy: 0.9622 - mean_iou: 0.8440 - val_loss: 0.0214 - val_accuracy: 0.9632 - val_mean_iou: 0.8083 - lr: 1.0000e-05
# Epoch 130/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0144 - accuracy: 0.9619 - mean_iou: 0.8453 - val_loss: 0.0214 - val_accuracy: 0.9632 - val_mean_iou: 0.8083 - lr: 1.0000e-05
# Epoch 131/1000
# 110/110 [==============================] - 25s 231ms/step - loss: 0.0139 - accuracy: 0.9619 - mean_iou: 0.8462 - val_loss: 0.0215 - val_accuracy: 0.9632 - val_mean_iou: 0.8089 - lr: 1.0000e-05
# Epoch 132/1000
# 110/110 [==============================] - 25s 232ms/step - loss: 0.0140 - accuracy: 0.9619 - mean_iou: 0.8470 - val_loss: 0.0215 - val_accuracy: 0.9632 - val_mean_iou: 0.8085 - lr: 1.0000e-05

# %% [markdown]
# ## Visualize the results

# %%
utils.plot_results(history)

# %%
# Evaluate the model on the validation set and print results
loss, accuracy, mean_iou = model.evaluate(X_val, y_val, batch_size=batch_size)

print(f"Validation Loss:\t{loss}")
print(f"Validation Accuracy:\t{accuracy}")
print(f"Validation Mean IoU:\t{mean_iou}")
# Out:
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0207 - accuracy: 0.9628 - mean_iou: 0.8095
# Validation Loss:	0.020730817690491676
# Validation Accuracy:	0.9627814888954163
# Validation Mean IoU:	0.8094623684883118

# %%
# Find a couple interesting samples to visualize
sample_indices = [1, 2, 3, 4, 7]

for sample_index in sample_indices:
    sample = X_val[sample_index]
    label = y_val[sample_index]

    # Plot the prediction and label
    utils.plot_prediction(model, sample, label, figsize=(10, 10))
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# ## Save and load the model

# %%
# Save the model and its weights
model.save('models/unet_da_v2.keras')
model.save_weights('models/unet_da_v2_weights.keras')

# %%
# Create a new model and load the weights
new_model = utils.get_unet_model(input_shape=input_shape, num_classes=num_classes)
new_model.load_weights('models/unet_da_v2_weights.keras')

# Compile the new model
new_model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', UpdatedMeanIoU(num_classes=num_classes)])

# Evaluate the new model on the validation set and print results
loss, accuracy, mean_iou = new_model.evaluate(X_val, y_val, batch_size=batch_size)

print(f"Validation Loss:\t{loss}")
print(f"Validation Accuracy:\t{accuracy}")
print(f"Validation Mean IoU:\t{mean_iou}")
# Out:
# 25/25 [==============================] - 2s 72ms/step - loss: 0.0207 - accuracy: 0.9927 - mean_iou: 0.8095
# Validation Loss:	0.020730817690491676
# Validation Accuracy:	0.9927283525466919
# Validation Mean IoU:	0.8094623684883118

# %%
# Evaluate the new model on the test set and print results
loss, accuracy, mean_iou = new_model.evaluate(X_test, y_test, batch_size=batch_size)

print(f"Test Loss:\t{loss}")
print(f"Test Accuracy:\t{accuracy}")
print(f"Test Mean IoU:\t{mean_iou}")
# Out:
# 25/25 [==============================] - 2s 70ms/step - loss: 0.0223 - accuracy: 0.9930 - mean_iou: 0.8030
# Test Loss:	0.022272620350122452
# Test Accuracy:	0.993030309677124
# Test Mean IoU:	0.8029640316963196
